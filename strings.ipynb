# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello python")
# Out:
# hello python

# %%
name = "atıl"

# %%
type(name)
# Out:
# str

# %%
'atil restaurant'
# Out:
# 'atil restaurant'

# %%
"atil restaurant"
# Out:
# 'atil restaurant'

# %%
"atil's restaurant"
# Out:
# "atil's restaurant"

# %%
name = "atil"

# %%
type(name)
# Out:
# str

# %%
name = "berat kafadar"

# %%
name.capitalize()
# Out:
# 'Berat kafadar'

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
x = 10

# %%
x = 8

# %%
name
# Out:
# 'berat kafadar'

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
name.capitalize()
# Out:
# 'Berat kafadar'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name
# Out:
# 'berat kafadar'

# %%
name.count("a")
# Out:
# 4

# %%
name.count("b")
# Out:
# 1

# %%
name.upper()
# Out:
# 'BERAT KAFADAR'

# %%
x = 10
y = 5

# %%
x + y
# Out:
# 15

# %%
z = x + y

# %%
z
# Out:
# 15

# %%
name
# Out:
# 'berat kafadar'

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'BERAT KAFADAR'

# %%
print(name.upper())
# Out:
# BERAT KAFADAR

# %%
help(name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
len(name) # length
# Out:
# 13

# %%
print("berat kafadar")
# Out:
# berat kafadar

# %%
print("berat \n kafadar")
# Out:
# berat
#  kafadar

# %%
print("berat \ kafadar")
# Out:
# berat \ kafadar

# %%
print("berat \tkafadar")
# Out:
# berat 	kafadar

# %% [markdown]
# # index

# %%
myString = "hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[0]
# Out:
# 'h'

# %%
myString[10]
# Out:
# 'o'

# %%
myString = "atil samancioglu"

# %%
myString[0]
# Out:
# 'a'

# %%
myString[15]
# Out:
# 'u'

# %%
len(myString)
# Out:
# 16

# %%
len(myString) - 1
# Out:
# 15

# %%
myName = "james hetfield"

# %%
len(myName)
# Out:
# 14

# %%
myName(13)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 myName(13)
#
# TypeError: 'str' object is not callable

# %%
myName[13]
# Out:
# 'd'

# %%
myName[len(myName)-1]
# Out:
# 'd'

# %%
myName[-1]
# Out:
# 'd'

# %%
myName[-2]
# Out:
# 'l'

# %%
barcode = "ABCDE123123982"

# %%
barcode[1]
# Out:
# 'B'

# %%
barcode[2]
# Out:
# 'C'

# %%
"A" + "B"
# Out:
# 'AB'

# %%
name = "berat"

# %%
surname = "kafadar"

# %%
fullname = name + " " + surname

# %%
fullname
# Out:
# 'berat kafadar'

# %%
fullname
# Out:
# 'berat kafadar'

# %%
fullname * 5
# Out:
# 'berat kafadarberat kafadarberat kafadarberat kafadarberat kafadar'

# %%
100 * "a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
barcode[0] + barcode[1] + barcode[2]
# Out:
# 'ABC'

# %%
# slicing, starting index, stopping index, stepping size

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
# barcode[starting index:stopping index:stepping size]

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[:3:]
# Out:
# 'ABC'

# %%
barcode[:5:]
# Out:
# 'ABCDE'

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[:6:]
# Out:
# 'ABCDE1'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[::-1]
# Out:
# '289321321EDCBA'

# %%
barcode[6:8:]
# Out:
# '23'

# %%
barcode[5:8:]
# Out:
# '123'

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(sub[, start[, end]], /) method of builtins.str instance
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Raises ValueError when the substring is not found.

# %%
name.index("b")
# Out:
# 0

# %%
name.split()
# Out:
# ['berat']

# %%
type(name.split())
# Out:
# list

# %% [markdown]
# # list

# %%
myString = "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
# list

# %%
myString
# Out:
# 'hello python'

# %%
myString[0]
# Out:
# 'h'

# %%
#myString[0] = "a"

# %%
#immutable - immutability

# %%
myString = "berat"

# %% [markdown]
# #list

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20 
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList = [10,20,30,40,50,60,70]

# %%
myList[0]
# Out:
# 10

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
len(myList)
# Out:
# 7

# %%
myList[len(myList)-1]
# Out:
# 70

# %%
myList[-1]
# Out:
# 70

# %%
myList[-2]
# Out:
# 60

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 1]

# %%
len(myList)
# Out:
# 9

# %%
myList.count(1)
# Out:
# 1

# %%
myList.index(40)
# Out:
# 3

# %%
help(myList.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80, 1]

# %%
myList.insert(2,31)

# %%
myList
# Out:
# [100, 20, 31, 30, 40, 50, 60, 70, 80, 1]

# %%
myList.pop()
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 31, 30, 40, 50, 60, 70, 80]

# %%
myList.remove(40)

# %%
myList
# Out:
# [100, 20, 31, 30, 50, 60, 70, 80]

# %%
myList.reverse()

# %%
myList
# Out:
# [80, 70, 60, 50, 30, 31, 20, 100]

# %%
myList.sort()

# %%
myList
# Out:
# [20, 30, 31, 50, 60, 70, 80, 100]

# %%
x = input("enter x")
# Out:
# enter x 10

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y:")
# Out:
# enter y: 20

# %%
z = input("enter z:")
# Out:
# enter z: 30

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
inputList
# Out:
# []

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[1]
# Out:
# '20'

# %%
inputList[1] * 2
# Out:
# '2020'

# %%
type(inputList[1])
# Out:
# str

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "python"

# %%
# int(myString)

# %%
# float(myString)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1]) * 2
# Out:
# 40

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
str(inputList)
# Out:
# "['10', '20', '30']"

# %%
nameList = ["atil","berat","a","b"]

# %%
type(nameList)
# Out:
# list

# %%
floatList = [3.13,2.5,10.2,100.123]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["atil",100,3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
mixedList
# Out:
# ['atil', 100, 3.14]

# %%
mixedList[1]
# Out:
# 100

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[2])
# Out:
# float

# %%
#nestedList

# %%
myNestedList = [10,20,3.14,"berat",[1,2,3]]

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'berat'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
x = myNestedList[0]

# %%
x
# Out:
# 10

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'berat', [1, 2, 3]]

# %%
myNestedList[4:1]
# Out:
# []

# %%
myNestedList[4:1:]
# Out:
# []

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
myNestedList[4],[1]
# Out:
# ([1, 2, 3], [1])

# %%
myNestedList[4],[2]
# Out:
# ([1, 2, 3], [2])

# %%
myNestedList[4:2:1]
# Out:
# []

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
myNestedList[4]
# Out:
# [2, 3]

# %%
myNestedList[4]
# Out:
# [2, 3]

# %%
myNestedList[4]
# Out:
# [2, 3]

# %%
smallList = myNestedList[-1]

# %%
smallList
# Out:
# [2, 3]

# %%
smallList
# Out:
# [2, 3]

# %%
smallList[0]
# Out:
# 2

# %%
myNestedList[4][1]
# Out:
# 3

# %%
myNestedList[4][0]
# Out:
# 2

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[1]
# Out:
# 'b'

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
lastList[2][1]
# Out:
# 'd'

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList[1:4:]
# Out:
# [20, 30, 40]

# %%
firstList[::2]
# Out:
# [10, 30, 50, 70]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
