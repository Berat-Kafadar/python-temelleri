# %%
4+3
# Out:
# 7

# %%
900 / 4
# Out:
# 225.0

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
10 - 100
# Out:
# -90

# %%
5 * 5 * 5 * 5 * 5 * 5
# Out:
# 15625

# %%
60 * 5
# Out:
# 300

# %%
age = 50

# %%
age * 2
# Out:
# 100

# %%
age
# Out:
# 50

# %%
age / 2
# Out:
# 25.0

# %%
aget
